# %% [markdown]
# ## Data Visualization Part A
# ### Data Set Name : Nutrition Facts for McDonald's Menu
# ### Author: Niveen Alsmadi
# ### Date: 23-June-2021

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the data you receive into a Pandas DataFrame

# %%
df= pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ### Analyze dataset

# %% [markdown]
# ## Note1:
# #### we can see by representing this graph that the quantity of protien Be as high as possible in lunches, as little as    possible in snaks nand moderate in breakfasts , so high protine by McDonald's in Chicken & Fish and thisis the normal , and   the lowest im Beverages

# %%
sns.relplot(x='Category', y='Protein', data=df, kind='line',aspect=2.5)

# %% [markdown]
# # ______________________________________________________________

# %% [markdown]
# ## Note2:
# #### we can see by representing this graph that the Chiken and fish hada high number of  Calories ,and coffe and tea had the least nymber of calories so dink tea gyes

# %%
sns.barplot(x='Category', y='Calories', data=df,ci=None, palette="Blues_d")
sns.set(rc={'figure.figsize':(30,20)})

# %% [markdown]
# ## Note3:
# #### by groping the total fat and sum the result we can see the quantity od suger between (0-200) , have zeroo Trans fat

# %%
fat=df.groupby('Total Fat (% Daily Value)',as_index=False).sum()
fat
# Out:
#     Total Fat (% Daily Value)  Calories  Calories from Fat  Total Fat  \
# 0                           0      5535                  0        0.0
# 1                           1      2720                 35        7.0
# 2                           2      1055                 40        4.5
# 3                           3       150                 20        2.0
# 4                           4       100                 20        2.5
# ..                        ...       ...                ...        ...
# 58                         80       800                470       52.0
# 59                         87      1090                510       56.0
# 60                         91       940                530       59.0
# 61                         93      1150                540       60.0
# 62                        182      1880               1060      118.0
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# ...

# %%
sns.relplot(x='Sugars', y='Trans Fat', data=fat,palette="Blues_d")

# %% [markdown]
# ## Summary

# %% [markdown]
# - Visual data by seaborn easy than plotting by matplotlib
# - grouping data make the colums more readable
# - like how we play with colors by pallets
# - seaborn give as the flexibility to plying with data
# - learn how resize the data plot
